# %%
import tensorflow
from keras.layers import Dense
from keras import Sequential
import pandas as pd

# %%
a=pd.read_csv(r"C:\Users\sinha\OneDrive\CODING\PYTHON\TENSORFLOW\csv\diabetes.csv")
a
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
x=a.iloc[:,:-1]
y=a.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x_train=st.fit_transform(x_train)
x_test=st.transform(x_test)

# %%
model=Sequential()
model.add(Dense(8,activation="relu",input_dim=8))
model.add(Dense(16,activation="relu"))
model.add(Dense(10,activation="relu"))
model.add(Dense(1,activation="relu"))
# Out:
# c:\Users\sinha\anaconda3\envs\ENV1\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           170 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 397 (1.55 KB)
#  Trainable params: 397 (1.55 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss="mse",optimizer="Adam")
model.fit(x_train,y_train,epochs=50,validation_split=0.2)
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.3096 - val_loss: 0.3170
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2855 - val_loss: 0.2702
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2676 - val_loss: 0.2554
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2460 - val_loss: 0.2309
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2148 - val_loss: 0.1959
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1927 - val_loss: 0.1767
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1777 - val_loss: 0.1794
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1696 - val_loss: 0.1682
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1652 - val_loss: 0.1679
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1620 - val_loss: 0.1664
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1595 - val_loss: 0.1681
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1572 - val_loss: 0.1658
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1560 - val_loss: 0.1665
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1542 - val_loss: 0.1663
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1534 - val_loss: 0.1655
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1520 - val_loss: 0.1654
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1512 - val_loss: 0.1645
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1495 - val_loss: 0.1661
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1483 - val_loss: 0.1652
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1472 - val_loss: 0.1656
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1455 - val_loss: 0.1645
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1442 - val_loss: 0.1662
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1436 - val_loss: 0.1653
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1420 - val_loss: 0.1665
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1413 - val_loss: 0.1654
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1402 - val_loss: 0.1662
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1393 - val_loss: 0.1667
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1395 - val_loss: 0.1663
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1379 - val_loss: 0.1663
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1376 - val_loss: 0.1661
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1380 - val_loss: 0.1663
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1368 - val_loss: 0.1669
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1363 - val_loss: 0.1657
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1352 - val_loss: 0.1675
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1349 - val_loss: 0.1677
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1345 - val_loss: 0.1682
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1337 - val_loss: 0.1680
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1331 - val_loss: 0.1666
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1323 - val_loss: 0.1672
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1320 - val_loss: 0.1675
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1315 - val_loss: 0.1679
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1323 - val_loss: 0.1682
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1308 - val_loss: 0.1684
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1304 - val_loss: 0.1685
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1300 - val_loss: 0.1696
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1294 - val_loss: 0.1685
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1304 - val_loss: 0.1682
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1294 - val_loss: 0.1691
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1278 - val_loss: 0.1688
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1280 - val_loss: 0.1696

# %%
pred=model.predict(x_test)
pred
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# array([[5.1293433e-01],
#        [0.0000000e+00],
#        [1.2963787e-03],
#        [2.8001329e-01],
#        [4.0820974e-01],
#        [5.0348079e-01],
#        [0.0000000e+00],
#        [6.8880129e-01],
#        [5.6327140e-01],
#        [3.5338160e-01],
#        [4.0605399e-01],
#        [9.5506549e-01],
#        [2.6251957e-01],
#        [2.8360477e-01],
#        [0.0000000e+00],
#        [5.5850852e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [5.1251960e-01],
#        [6.1973697e-01],
#        [2.9670364e-01],
#        [0.0000000e+00],
#        [7.5084245e-01],
#        [0.0000000e+00],
#        [5.8805245e-01],
#        [9.0622538e-01],
#        [1.6818441e-02],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [9.6058893e-01],
#        [3.6497632e-01],
#        [7.3637730e-01],
#        [8.7487853e-01],
#        [7.9619986e-01],
#        [8.0254811e-01],
#        [1.4210043e+00],
#        [2.9887798e-01],
#        [3.6993182e-01],
#        [8.6764729e-01],
#        [0.0000000e+00],
#        [5.1885003e-01],
#        [5.2349180e-01],
#        [3.4306949e-01],
#        [0.0000000e+00],
#        [7.0781487e-01],
#        [6.9857347e-01],
#        [0.0000000e+00],
#        [3.8356569e-01],
#        [5.7379687e-01],
#        [0.0000000e+00],
#        [5.9812135e-01],
#        [5.4094565e-01],
#        [3.7280723e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [3.5206893e-01],
#        [0.0000000e+00],
#        [4.5367059e-01],
#        [4.0282950e-01],
#        [8.1872034e-01],
#        [4.8138681e-01],
#        [4.2737603e-01],
#        [6.3784212e-01],
#        [0.0000000e+00],
#        [9.3828762e-01],
#        [0.0000000e+00],
#        [7.7914476e-01],
#        [0.0000000e+00],
#        [7.3209834e-01],
#        [5.3883588e-01],
#        [0.0000000e+00],
#        [2.9085755e-01],
#        [0.0000000e+00],
#        [2.5380626e-02],
#        [4.6377680e-01],
#        [4.4475368e-01],
#        [6.1258890e-02],
#        [0.0000000e+00],
#        [1.0055760e-01],
#        [5.1795655e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.2892401e-01],
#        [2.7898639e-01],
#        [7.7782899e-01],
#        [9.4035190e-01],
#        [2.5202197e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [1.1570508e-01],
#        [0.0000000e+00],
#        [3.2158363e-01],
#        [5.1476008e-01],
#        [8.6541700e-01],
#        [2.6818681e-01],
#        [0.0000000e+00],
#        [1.8727598e-01],
#        [4.9114898e-03],
#        [8.3961189e-01],
#        [0.0000000e+00],
#        [6.4627510e-01],
#        [4.2979905e-01],
#        [8.4554660e-01],
#        [3.9154500e-02],
#        [4.2181227e-01],
#        [8.8784075e-01],
#        [0.0000000e+00],
#        [8.5813326e-01],
#        [0.0000000e+00],
#        [6.6522980e-01],
#        [0.0000000e+00],
#        [4.7812510e-01],
#        [0.0000000e+00],
#        [4.7959051e-01],
#        [7.5630391e-01],
#        [2.6599297e-01],
#        [0.0000000e+00],
#        [3.1931680e-01],
#        [0.0000000e+00],
#        [2.7102757e-01],
#        [3.9483222e-01],
#        [0.0000000e+00],
#        [5.0679648e-01],
#        [4.8477161e-01],
#        [2.5226802e-01],
#        [8.6674964e-01],
#        [3.4615192e-01],
#        [8.1421846e-01],
#        [5.5788231e-01],
#        [7.4268848e-01],
#        [0.0000000e+00],
#        [4.8776606e-01],
#        [8.2572180e-01],
#        [1.0480455e-01],
#        [2.2916362e-01],
#        [7.1090704e-01],
#        [7.5906146e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [3.8399926e-01],
#        [5.9186172e-01],
#        [0.0000000e+00],
#        [4.4277516e-01],
#        [0.0000000e+00],
#        [0.0000000e+00],
#        [4.2087275e-01],
#        [6.5925539e-01],
#        [0.0000000e+00],
#        [3.6622864e-01],
#        [4.1367611e-01],
#        [3.5486728e-01]], dtype=float32)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,pred)*100
# Out:
# 18.89486312866211
